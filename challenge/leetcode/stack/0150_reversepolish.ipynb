# %% [markdown]
# You are given an array of strings tokens that represents an arithmetic expression in a Reverse Polish Notation.
#
# Evaluate the expression. Return an integer that represents the value of the expression.
#
# Note that:
#
# The valid operators are '+', '-', '*', and '/'.
# Each operand may be an integer or another expression.
# The division between two integers always truncates toward zero.
# There will not be any division by zero.
# The input represents a valid arithmetic expression in a reverse polish notation.
# The answer and all the intermediate calculations can be represented in a 32-bit integer.
#
#
# Example 1:
#
# Input: tokens = ["2","1","+","3","*"]
# Output: 9
# Explanation: ((2 + 1) * 3) = 9
# Example 2:
#
# Input: tokens = ["4","13","5","/","+"]
# Output: 6
# Explanation: (4 + (13 / 5)) = 6
# Example 3:
#
# Input: tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]
# Output: 22
# Explanation: ((10 * (6 / ((9 + 3) * -11))) + 17) + 5
# = ((10 * (6 / (12 * -11))) + 17) + 5
# = ((10 * (6 / -132)) + 17) + 5
# = ((10 * 0) + 17) + 5
# = (0 + 17) + 5
# = 17 + 5
# = 22

# %%
from typing import List
import math

class Solution:
    def evalRPN(self, tokens: List[str]) -> int:
        tokens.reverse()
        print(tokens)
        polishstack = []
        while len(tokens) > 0:
            if tokens[-1] not in ['+','-','*','/']:
               polishstack.append(int(tokens.pop()))
               print(f'p token = {polishstack}')
            elif tokens[-1] == '+':
                n = polishstack[-2] + polishstack[-1]
                print('+',n)
                tokens.pop()
                # print(tokens)
                polishstack.pop()
                polishstack.pop()
                polishstack.append(n)
                print('p+ = ', polishstack)
            elif tokens[-1] == '-':
                n = polishstack[-2] - polishstack[-1]
                print('-',n)
                tokens.pop()
                # print(tokens)
                polishstack.pop()
                polishstack.pop()
                polishstack.append(n)
                print('p- = ', polishstack)
            elif tokens[-1] == '*':
                n = polishstack[-2] * polishstack[-1]
                print('*',n)
                tokens.pop()
                # print(tokens)
                polishstack.pop()
                polishstack.pop()
                polishstack.append(n)
                print('p* = ', polishstack)
            elif tokens[-1] == '/':
                n = math.trunc(polishstack[-2] / polishstack[-1])
                print('/',n)
                tokens.pop()
                # print(tokens)
                polishstack.pop()
                polishstack.pop()
                polishstack.append(n)
                print('p/ = ', polishstack)
        return(polishstack[0])

tokens = ["10","6","9","3","+","-11","*","/","*","17","+","5","+"]
s = Solution()
print(s.evalRPN(tokens))
# Out:
# ['+', '5', '+', '17', '*', '/', '*', '-11', '+', '3', '9', '6', '10']
# p token = [10]
# p token = [10, 6]
# p token = [10, 6, 9]
# p token = [10, 6, 9, 3]
# + 12
# p+ =  [10, 6, 12]
# p token = [10, 6, 12, -11]
# * -132
# p* =  [10, 6, -132]
# / 0
# p/ =  [10, 0]
# * 0
# p* =  [0]
# p token = [0, 17]
# + 17
# p+ =  [17]
# p token = [17, 5]
# + 22
# p+ =  [22]
# 22

# %%
Explanation: ((10 * (6 / ((9 + 3) * -11))) + 17) + 5
= ((10 * (6 / (12 * -11))) + 17) + 5
= ((10 * (6 / -132)) + 17) + 5
= ((10 * 0) + 17) + 5
= (0 + 17) + 5
= 17 + 5
= 22

# %%
class Solution:
    def evalRPN(self, tokens: List[str]) -> int:
        stack = []
        for t in tokens:
            if t not in {"+", "-", "*", "/"}:
                stack.append(int(t))
            else:
                b, a = stack.pop(), stack.pop()
                if t == "+": stack.append(a + b)
                elif t == "-": stack.append(a - b)
                elif t == "*": stack.append(a * b)
                else: stack.append(trunc(a / b))
        return stack[0]
